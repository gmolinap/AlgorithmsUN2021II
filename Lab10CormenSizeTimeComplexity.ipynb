# %% [markdown]
# #LAB 10 Maximum problem size given an available time and a time complexity – Cormen

# %% [markdown]
# # 1.(10  nanoseconds by instruction)
#
# Asuuming that you can execute a 100 million instructions $100 \times 10^6$ every second, i.e. each instrcution takes 10 nanoseconds, 10 $\eta s  ={10^{-8}} s $. If you have algorithms take $\bf{ Time\ Complexity}$ steps to solve a poblem of size $n$ as specified in column one. What is the size of the largest porblem that you can solve in the time specified in row one?
# $$
# \begin{array}{|c|c|c|c|c|c|c|c|}
#  \hline
#  \bf{ Time\ Complexity} & Second  & Minute  & Hour & Day & Year & Century & Mileniun  \\
#   \hline\\
# \lg(n) &  2^{10^{8}} &  2^{6\times 10^{9}} & 2^{36 \times 10^{11}} & 2^{864 \times 10^{11}}  & 2^{31536 \times 10^{11}} & 2^{31536 \times 10^{13}} & 2^{31536 \times 10^{14}}  \\
#    \hline\\
# \lg^2(n) & 2^{5 \times10^{17}} &  2^{150 \times10^{17}} & 2^{9 \times10^{20}} & 2^{216 \times10^{20}} & 2^{7884 \times10^{21}} & 2^{7884 \times10^{23}} & 2^{7884 \times10^{24}} \\
#    \hline\\
# \sqrt{n} & 10^{14}  & 36 \times 10^{18}  & 1296 \times 10^{23} & 746496 \times 10^{20} & 994519296 \times 10^{22} & 994519296 \times 10^{26} & 994519296 \times 10^{28} \\
#  \hline
#  n &  100*10^{6}  & 6000 \times 10^{6}  & 360000 \times 10^{6} & 8640000 \times 10^{6} & 3153600000 \times 10^{6} & 315360000000 \times 10^{6} & 3153600000000 \times 10^{6} \\
#  \hline
#  n\lg(n) & 4523071   &  216677120 & 10800938300 & 228957337705 & 68610956750570 & 6016277763015247 & 56665093434063128 \\
#  \hline
#  n^2 &  10000  & 77459.7  & 600000 & 2939387.7 & 56156922.99 & 561569229.9 & 1775837830 \\
#  \hline
#   n^3 &  464  &  1817.1 & 7113.8 & 20519.7 & 146645.5 & 680668.3 & 1466455.4 \\
#  \hline
#   n^4 &  100  &  278.3 & 774.6 & 1714.5 & 4214.1 & 13326.1 &  7493.8  \\
#  \hline
#   2^n &  26 &  32.5 & 38.4 & 42.9 & 51.4 & 58.1 & 61.45 \\
#  \hline
#  n! &  14  & 16  & 17 & 19 & 20 & 22 & 23  \\
#  \hline
#  n^n &  8 &  9 & 11 & 11 & 13 & 14 & 15  \\
#  \hline
# \end{array}
# $$

# %% [markdown]
# $\bf{ Time\ Complexity\ \lg(n) }$
#
# $Second$
# $$ \lg(n) \times 100*10^{-6}\ s\le 1\ s$$
# $$ \lg(n) \le 100 \times 10^{6}$$
# $$ 2^{\lg(n)} \le 2^{100 \times 10^{6}}$$
# $$ n \le 2^{100 \times 10^{6}}$$
#
# $Minute$
# $$ \lg(n) \times 100*10^{-6}\ s \le 60\ s$$
# $$ \lg(n) \le 6000 \times 10^{6}$$
# $$ 2^{\lg(n)} \le 2^{6000 \times 10^{6}}$$
# $$ n \le 2^{6000 \times 10^{6}}$$
#
# $Hour$
# $$ \lg(n) \times 100*10^{-6}\ s \le 3600\ s$$
# $$ \lg(n) \le 360000 \times 10^{6}$$
# $$ 2^{\lg(n)} \le 2^{360000 \times 10^{6}}$$
# $$ n \le 2^{360000 \times 10^{6}}$$
#
# $Day$
# $$ \lg(n) \times 100*10^{-6}\ s \le 86400\ s$$
# $$ \lg(n) \le 8640000 \times 10^{6}$$
# $$ 2^{\lg(n)} \le 2^{8640000 \times 10^{6}}$$
# $$ n \le 2^{8640000 \times 10^{6}}$$
#
# $Year$
# $$ \lg(n) \times 100*10^{-6}\ s \le 31536000\ s$$
# $$ \lg(n) \le 3153600000 \times 10^{6}$$
# $$ 2^{\lg(n)} \le 2^{3153600000 \times 10^{6}}$$
# $$ n \le 2^{3153600000 \times 10^{6}}$$
#
# $Century$
# $$ \lg(n) \times 100*10^{-6}\ s \le 3153600000\ s$$
# $$ \lg(n) \le 315360000000 \times 10^{6}$$
# $$ 2^{\lg(n)} \le 2^{315360000000 \times 10^{6}}$$
# $$ n \le 2^{315360000000 \times 10^{6}}$$
#
# $Milenium$
# $$ \lg(n) \times 100*10^{-6}\ s \le 31536000000\ s$$
# $$ \lg(n) \le 3153600000000 \times 10^{6}$$
# $$ 2^{\lg(n)} \le 2^{3153600000000 \times 10^{6}}$$
# $$ n \le 2^{3153600000000 \times 10^{6}}$$
#
# $\bf{ Time\ Complexity\ \lg^2(n) }$
#
# $Second$
# $$ \lg^2(n) \times 100*10^{-6}\ s\le 1\ s$$
# $$ \lg^2(n) \le 1 * 10^{6}$$
# $$ 2^{\lg(n)^2} \le 2^{10^{6}}$$
# $$ n^2 \le 2^{10^{6}}$$
# $$ n \le 2^{5 \times10^{17}}$$
#
# $Minute$
# $$ \lg^2(n) \times 100*10^{-6}\ s\le 60\ s$$
# $$ \lg^2(n) \le 60 * 10^{6}$$
# $$ 2^{\lg(n)^2} \le 2^{6000 \times 10^{6}}$$
# $$ n^2 \le 2^{6000 \times 10^{6}}$$
# $$ n \le 2^{15000 \times10^{17}}$$
#
# $Hour$
# $$ \lg^2(n) \times 100*10^{-6}\ s\le 3600\ s$$
# $$ \lg^2(n) \le 3600 * 10^{6}$$
# $$ 2^{\lg(n)^2} \le 2^{3600 \times 10^{6}}$$
# $$ n^2 \le 2^{360000 \times 10^{6}}$$
# $$ n \le 2^{900000 \times10^{17}}$$
#
# $Day$
# $$ \lg^2(n) \times 100*10^{-6}\ s\le 86400\ s$$
# $$ \lg^2(n) \le 8640000 * 10^{6}$$
# $$ 2^{\lg(n)^2} \le 2^{8640000 \times 10^{6}}$$
# $$ n^2 \le 2^{8640000 \times 10^{6}}$$
# $$ n \le 2^{21600000 \times10^{17}}$$
#
# $Year$
# $$ \lg^2(n) \times 100*10^{-6}\ s\le 31536000\ s$$
# $$ \lg^2(n) \le 3153600000 * 10^{6}$$
# $$ 2^{\lg(n)^2} \le 2^{3153600000 \times 10^{6}}$$
# $$ n^2 \le 2^{3153600000 \times 10^{6}}$$
# $$ n \le 2^{7884000000 \times10^{17}}$$
#
# $Century$
# $$ \lg^2(n) \times 100*10^{-6}\ s\le 3153600000 \ s$$
# $$ \lg^2(n) \le 315360000000 * 10^{6}$$
# $$ 2^{\lg(n)^2} \le 2^{315360000000 \times 10^{6}}$$
# $$ n^2 \le 2^{315360000000 \times 10^{6}}$$
# $$ n \le 2^{788400000000 \times10^{17}}$$
#
# $Milenium$
# $$ \lg^2(n) \times 100*10^{-6}\ s\le 31536000000\ s$$
# $$ \lg^2(n) \le 3153600000000 * 10^{6}$$
# $$ 2^{\lg(n)^2} \le 2^{3153600000000 \times 10^{6}}$$
# $$ n^2 \le 2^{3153600000000 \times 10^{6}}$$
# $$ n \le 2^{7884000000000 \times10^{17}}$$
#
# $\bf{ Time\ Complexity  \sqrt{n} }$
#
# $Second$
# $$ \sqrt{n} \times 100*10^{-6}\ s\le 1\ s$$
# $$ \sqrt{n} \le 100 * 10^{6}$$
# $$ ({\sqrt{n}})^2 \le 100*({10^{6}})^2$$
# $$ n \le 100 \times 10^{12}$$
#
# $Minute$
# $$ \sqrt{n} \times 100*10^{-6}\ s\le 60\ s$$
# $$ \sqrt{n} \le 6000 * 10^{6}$$
# $$ ({\sqrt{n}})^2 \le 6000^2 \times ({10^{6}})^2$$
# $$ n \le 36000000 \times 10^{12}$$
#
# $Hour$
# $$ \sqrt{n} \times 100*10^{-6}\ s\le 3600\ s$$
# $$ \sqrt{n} \le 360000 * 10^{6}$$
# $$ ({\sqrt{n}})^2 \le 360000^2 \times ({10^{6}})^2$$
# $$ n \le 129600000000000 \times 10^{12}$$
#
# $Day$
# $$ \sqrt{n} \times 100*10^{-6}\ s\le 86400\ s$$
# $$ \sqrt{n} \le 8640000 * 10^{6}$$
# $$ ({\sqrt{n}})^2 \le 8640000^2 \times ({10^{6}})^2$$
# $$ n \le 74649600000000 \times 10^{12}$$
#
# $Year$
# $$ \sqrt{n} \times 100*10^{-6}\ s\le 31536000\ s$$
# $$ \sqrt{n} \le 3153600000 * 10^{6}$$
# $$ ({\sqrt{n}})^2 \le 3153600000^2 \times ({10^{6}})^2$$
# $$ n \le 9945192960000000000 \times 10^{12}$$
#
# $Century$
# $$ \sqrt{n} \times 100*10^{-6}\ s\le 3153600000\ s$$
# $$ \sqrt{n} \le 315360000000 * 10^{6}$$
# $$ ({\sqrt{n}})^2 \le 315360000000^2 \times ({10^{6}})^2$$
# $$ n \le 99451929600000000000000 \times 10^{12}$$
#
# $Milenium$
# $$ \sqrt{n} \times 100*10^{-6}\ s\le 31536000000\ s$$
# $$ \sqrt{n} \le 3153600000000 * 10^{6}$$
# $$ ({\sqrt{n}})^2 \le 3153600000000^2 \times ({10^{6}})^2$$
# $$ n \le 9945192960000000000000000 \times 10^{12}$$
#
# $\bf{ Time\ Complexity  \ n }$
#
# $Second$
# $$ \ n \times 100*10^{-6}\ s\le 1\ s$$
# $$ \ n \le 1*100 * 10^{6}$$
# $$ n \le 100*10^{6}$$
#
# $Minute$
# $$ \ n \times 100*10^{-6}\ s\le 60\ s$$
# $$ \ n \le 6000 * 10^{6}$$
# $$ n \le 6000 \times 10^{6}$$
#
# $Hour$
# $$ \ n \times 100*10^{-6}\ s\le 3600\ s$$
# $$ \ n \le 360000 * 10^{6}$$
# $$ n \le 360000 \times 10^{6}$$
#
# $Day$
# $$ \ n \times 100*10^{-6}\ s\le 86400\ s$$
# $$ \ n \le 8640000 * 10^{6}$$
# $$ n \le 8640000 \times 10^{6}$$
#
# $Year$
# $$ \ n \times 100*10^{-6}\ s\le 31536000\ s$$
# $$ \ n \le 3153600000 * 10^{6}$$
# $$ n \le 3153600000 \times 10^{6}$$
#
# $Century$
# $$ \ n \times 100*10^{-6}\ s\le 3153600000\ s$$
# $$ \ n \le 315360000000 * 10^{6}$$
# $$ n \le 315360000000 \times 10^{6}$$
#
# $Milenium$
# $$ \ n \times 100*10^{-6}\ s\le 31536000000\ s$$
# $$ \ n \le 3153600000000 * 10^{6}$$
# $$ n \le 3153600000000 \times 10^{6}$$
#
# $\bf{ Time\ Complexity\ \ n \ lg(n) }$
#
# $$ Second: n <= 4523071 $$
# $$ Minute: n <= 216677120 $$
# $$ Hour: n <= 10800938300 $$
# $$ Day: n <= 228957337705 $$
# $$ Year: n <= 68610956750570 $$
# $$ Century: n <= 6016277763015247 $$
# $$ Milenium: n <= 56665093434063128 $$
#
# $\bf{ Time\ Complexity\ n^2 }$
#
# $Second$
# $$  n^2 \times 100*10^{-6}\ s\le 1\ s$$
# $$  n^2 \le  100*10^{6}$$
# $$ \sqrt{n^2} \le \sqrt{100*10^{6}}$$
# $$ n \le 10^6 = 10000 $$
#
# $Minute$
# $$  n^2 \times 100*10^{-6}\ s\le 60\ s$$
# $$  n^2 \le 6000 \times 10^{6}$$
# $$ \sqrt{n^2} \le \sqrt{6000 \times10^{6}}$$
# $$ n \le 77459.7 $$
#
# $Hour$
# $$  n^2 \times 10^{-6}\ s\le 3600\ s$$
# $$  n^2 \le 360000 \times 10^{6}$$
# $$ \sqrt{n^2} \le \sqrt{360000 \times10^{6}}$$
# $$ n \le 600000 $$
#
# $Day$
# $$  n^2 \times 100*10^{-6}\ s\le 86400\ s$$
# $$  n^2 \le 8640000 \times 10^{6}$$
# $$ \sqrt{n^2} \le \sqrt{8640000 \times10^{6}}$$
# $$ n \le 2939387.7 $$
#
# $Year$
# $$  n^2 \times 100*10^{-6}\ s\le 31536000\ s$$
# $$  n^2 \le 3153600000 \times 10^{6}$$
# $$ \sqrt{n^2} \le \sqrt{3153600000 \times10^{6}}$$
# $$ n \le 56156922.99 $$
#
# $Century$
# $$  n^2 \times 100*10^{-6}\ s\le 3153600000\ s$$
# $$  n^2 \le 315360000000 \times 10^{6}$$
# $$ \sqrt{n^2} \le \sqrt{315360000000 \times10^{6}}$$
# $$ n \le 561569229.9 $$
#
# $Milenium$
# $$  n^2 \times 100*10^{-6}\ s\le 31536000000\ s$$
# $$  n^2 \le 3153600000000 \times 10^{6}$$
# $$ \sqrt{n^2} \le \sqrt{3153600000000 \times10^{6}}$$
# $$ n \le 1775837830 $$
#
# $\bf{ Time\ Complexity\ n^3 }$
#
# $Second$
# $$  n^3 \times 100*10^{-6}\ s\le 1\ s$$
# $$  n^3 \le  100*10^{6}$$
# $$ \sqrt[3]{n^3} \le \sqrt[3]{100*10^{6}}$$
# $$ n \le  464 $$
#
# $Minute$
# $$  n^3 \times 100*10^{-6}\ s\le 60\ s$$
# $$  n^3 \le 6000 \times 10^{6}$$
# $$ \sqrt[3]{n^3} \le \sqrt[3]{6000 \times10^{6}}$$
# $$ n \le 1817.1 $$
#
# $Hour$
# $$  n^3 \times 100*10^{-6}\ s\le 3600\ s$$
# $$  n^3 \le 360000 \times 10^{6}$$
# $$ \sqrt[3]{n^3} \le \sqrt[3]{360000 \times10^{6}}$$
# $$ n \le 7113.8 $$
#
# $Day$
# $$  n^3 \times 100*10^{-6}\ s\le 86400\ s$$
# $$  n^3 \le 8640000 \times 10^{6}$$
# $$ \sqrt[3]{n^3} \le \sqrt[3]{8640000 \times10^{6}}$$
# $$ n \le 20519.7 $$
#
# $Year$
# $$  n^3 \times 100*10^{-6}\ s\le 31536000\ s$$
# $$  n^3 \le 3153600000 \times 10^{6}$$
# $$ \sqrt[3]{n^3} \le \sqrt[3]{3153600000 \times10^{6}}$$
# $$ n \le 146645.5 $$
#
# $Century$
# $$  n^3 \times 100*10^{-6}\ s\le 3153600000\ s$$
# $$  n^3 \le 315360000000 \times 10^{6}$$
# $$ \sqrt[3]{n^3} \le \sqrt[3]{315360000000 \times10^{6}}$$
# $$ n \le 680668.3 $$
#
# $Milenium$
# $$  n^3 \times 100*10^{-6}\ s\le 31536000000\ s$$
# $$  n^3 \le 3153600000000 \times 10^{6}$$
# $$ \sqrt[3]{n^3} \le \sqrt{3153600000000 \times10^{6}}$$
# $$ n \le 1466455.4 $$
#
# $\bf{ Time\ Complexity\ n^4 }$
#
# $Second$
# $$  n^4 \times 100*10^{-6}\ s\le 1\ s$$
# $$  n^4 \le 100* 10^{6}$$
# $$ \sqrt[4]{n^4} \le \sqrt[4]{100*10^{6}}$$
# $$ n \le = 100 $$
#
# $Minute$
# $$  n^4 \times 100*10^{-6}\ s\le 60\ s$$
# $$  n^4 \le 6000 \times 10^{6}$$
# $$ \sqrt[4]{n^4} \le \sqrt[4]{6000 \times10^{6}}$$
# $$ n \le 278.3 $$
#
# $Hour$
# $$  n^4 \times 100*10^{-6}\ s\le 3600\ s$$
# $$  n^4 \le 360000 \times 10^{6}$$
# $$ \sqrt[4]{n^4} \le \sqrt[4]{360000 \times10^{6}}$$
# $$ n \le 774.6 $$
#
# $Day$
# $$  n^4 \times 100*10^{-6}\ s\le 86400\ s$$
# $$  n^4 \le 8640000 \times 10^{6}$$
# $$ \sqrt[4]{n^4} \le \sqrt[4]{8640000 \times10^{6}}$$
# $$ n \le 1714.5 $$
#
# $Year$
# $$  n^4 \times 100*10^{-6}\ s\le 31536000\ s$$
# $$  n^4 \le 3153600000 \times 10^{6}$$
# $$ \sqrt[4]{n^4} \le \sqrt[4]{3153600000 \times10^{6}}$$
# $$ n \le 4214.1 $$
#
# $Century$
# $$  n^4 \times 10^{-6}\ s\le 3153600000\ s$$
# $$  n^4 \le 315360000000 \times 100^{6}$$
# $$ \sqrt[4]{n^4} \le \sqrt[4]{315360000000 \times10^{6}}$$
# $$ n \le 13326.1 $$
#
# $Milenium$
# $$  n^4 \times 10^{-6}\ s\le 31536000000\ s$$
# $$  n^4 \le 3153600000000 \times 100^{6}$$
# $$ \sqrt[4]{n^4} \le \sqrt[4]{3153600000000 \times10^{6}}$$
# $$ n \le 7493.8 $$
#
# $\bf{ Time\ Complexity\ 2^n }$
#
# $Second$
# $$  2^n \times 100*10^{-6}\ s\le 1\ s$$
# $$  2^n \le  100*10^{6}$$
# $$ \ n \le \log_{2}(100*10^{6})$$
# $$ n \le  = 26 $$
#
# $Minute$
# $$  2^n \times 100*10^{-6}\ s\le 60\ s$$
# $$  2^n \le 6000 \times 10^{6}$$
# $$ \ n \le \ log_{2}(6000) + log_{2}(10^{6})$$
# $$ n \le 32.5 $$
#
# $Hour$
# $$  2^n \times 100*10^{-6}\ s\le 3600\ s$$
# $$  2^n \le 360000 \times 10^{6}$$
# $$ \ n \le \ log_{2}(3600) + log_{2}(100^{6})$$
# $$ n \le 38.4 $$
#
# $Day$
# $$  2^n \times 100*10^{-6}\ s\le 86400\ s$$
# $$  2^n \le 8640000 \times 10^{6}$$
# $$ \ n \le \ log_{2}(8640000) + log_{2}(10^{6})$$
# $$ n \le 42.9 $$
#
# $Year$
# $$  2^n \times 10^{-6}\ s\le 31536000\ s$$
# $$  2^n \le 3153600000 \times 10^{6}$$
# $$ \ n \le \ log_{2}(3153600000) + log_{2}(10^{6})$$
# $$ n \le 51.4 $$
#
# $Century$
# $$  2^n \times 10^{-6}\ s\le 3153600000\ s$$
# $$  2^n \le 315360000000 \times 10^{6}$$
# $$ \ n \le \ log_{2}(315360000000) + log_{2}(10^{6})$$
# $$ n \le 58.1 $$
#
# $Milenium$
# $$  2^n \times 10^{-6}\ s\le 31536000000\ s$$
# $$  2^n \le 3153600000000 \times 10^{6}$$
# $$ \ n \le \ log_{2}(3153600000000) + log_{2}(10^{6})$$
# $$ n \le 61.45 $$
#
# $\bf{ Time\ Complexity\ n! }$
#
# $Second$
# $$  n! \times 100*10^{-6}\ s\le 1\ s$$
# $$  n! \le  100*10^{6}$$
# $$ n \le 100*10^{6} \ge 11! $$
#
# $Minute$
# $$  n! \times 100*10^{-6}\ s\le 60\ s$$
# $$  n! \le  6000 \times 10^{6}$$
# $$ n \le 6000 \times 10^{6} \ge 12! $$
#
# $Hour$
# $$  n! \times 100*10^{-6}\ s\le 3600\ s$$
# $$  n! \le  360000 \times 10^{6}$$
# $$ n \le 360000 \times 10^{6} \ge 14! $$
#
# $Day$
# $$  n! \times 100*10^{-6}\ s\le 86400\ s$$
# $$  n! \le  8640000 \times 10^{6}$$
# $$ n \le 8640000 \times 100^{6} \ge 15! $$
#
# $Year$
# $$  n! \times 100*10^{-6}\ s\le 31536000\ s$$
# $$  n! \le  3153600000 \times 10^{6}$$
# $$ n \le 3153600000 \times 10^{6} \ge 17! $$
#
# $Century$
# $$  n! \times 100*10^{-6}\ s\le 3153600000\ s$$
# $$  n! \le  315360000000 \times 10^{6}$$
# $$ n \le 315360000000 \times 10^{6} \ge 19! $$
#
# $Milenium$
# $$  n! \times 100*10^{-6}\ s\le 31536000000\ s$$
# $$  n! \le  3153600000000 \times 10^{6}$$
# $$ n \le 3153600000000 \times 10^{6} \ge 20! $$
#
# $\bf{ Time\ Complexity\ n^n }$
#
# $$ Second: n <= 8 $$
# $$ Minute: n <= 9 $$
# $$ Hour: n <= 11 $$
# $$ Day: n <= 11 $$
# $$ Year: n <= 13 $$
# $$ Century: n <= 14 $$
# $$ Milenium: n <= 15 $$

# %%
import math

def nlogn(t):
    n = 2
    max = t*100*10**6
    nlogn = 0
    while(nlogn < max):
        n = max/math.log2(n)
        nlogn += (max-nlogn)/2
    return int(n)

print("Second: \n n <=", nlogn(1))
print("Minute: \n n <=", nlogn(60))
print("Hour: \n n <=", nlogn(3600))
print("Day: \n n <=", nlogn(86400))
print("Year: \n n <=", nlogn(31536000))
print("Century: \n n <=", nlogn(3153600000))
print("Milenium: \n n <=", nlogn(31536000000))
# Out:
# Second:
#  n <= 4523071
# Minute:
#  n <= 216677120
# Hour:
#  n <= 10800938300
# Day:
#  n <= 228957337705
# Year:
#  n <= 68610956750570
# Century:
#  n <= 6016277763015247
# Milenium:
#  n <= 56665093434063128

# %%
import math

def nfac(t):
    n = 0
    max = t*100*10**6
    nf = 1
    while(nf <= max):
        n = n + 1
        nf = math.factorial(n)
    return int(n-1)

print("Second: \n n <=", nfac(1))
print("Minute: \n n <=", nfac(60))
print("Hour: \n n <=", nfac(3600))
print("Day: \n n <=", nfac(86400))
print("Year: \n n <=", nfac(31536000))
print("Century: \n n <=", nfac(3153600000))
print("Milenium: \n n <=", nfac(31536000000))
# Out:
# Second:
#  n <= 11
# Minute:
#  n <= 12
# Hour:
#  n <= 14
# Day:
#  n <= 15
# Year:
#  n <= 17
# Century:
#  n <= 19
# Milenium:
#  n <= 20

# %%
import math

def nn(t):
    n = 0
    max = t*100*10**6
    nn = 1
    while(nn <= max):
        n = n + 1
        nn = n**n
    return int(n-1)

print("Second: \n n <=", nn(1))
print("Minute: \n n <=", nn(60))
print("Hour: \n n <=", nn(3600))
print("Day: \n n <=", nn(86400))
print("Year: \n n <=", nn(31536000))
print("Century: \n n <=", nn(3153600000))
print("Milenium: \n n <=", nn(31536000000))
# Out:
# Second:
#  n <= 8
# Minute:
#  n <= 9
# Hour:
#  n <= 11
# Day:
#  n <= 11
# Year:
#  n <= 13
# Century:
#  n <= 14
# Milenium:
#  n <= 15
